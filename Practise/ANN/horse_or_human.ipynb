# %%
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('horses\\horse01-0.png')
cv2.imshow('image', image)
cv2.waitKey(0)
# Out:
# -1

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
