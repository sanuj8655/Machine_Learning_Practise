# %% [markdown]
# ## SVM Classification

# %% [markdown]
# ### import required package

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### read data from source and describing

# %%
df = pd.read_csv('hearing_test.csv')
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
print(df.columns)
# Out:
# Index(['age', 'physical_score', 'test_result'], dtype='object')

# %%
print(df.describe())
# Out:
#                age  physical_score  test_result
# count  5000.000000     5000.000000  5000.000000
# mean     51.609000       32.760260     0.600000
# std      11.287001        8.169802     0.489947
# min      18.000000       -0.000000     0.000000
# 25%      43.000000       26.700000     0.000000
# 50%      51.000000       35.300000     1.000000
# 75%      60.000000       38.900000     1.000000
# max      90.000000       50.000000     1.000000

# %%
## chec for data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             5000 non-null   float64
#  1   physical_score  5000 non-null   float64
#  2   test_result     5000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 117.3 KB
# None

# %%
sns.pairplot(df)

# %% [markdown]
# ### check the relation between variables

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
# #T_53637_row0_col0,#T_53637_row1_col1,#T_53637_row2_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_53637_row0_col1,#T_53637_row0_col2,#T_53637_row1_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_53637_row1_col2{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_53637_row2_col0{
#             background-color:  #eff9ec;
#             color:  #000000;
#         }#T_53637_row2_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }</style><table id="T_53637_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >physical_score</th>        <th class="col_heading level0 col2" >test_result</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53637_level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_53637_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_53637_row0_col1" class="data row0 col1" >-0.782146</td>
#                         <td id="T_53637_row0_col2" class="data row0 col2" >-0.683171</td>
#             </tr>
#             <tr>
#                         <th id="T_53637_level0_row1" class="row_heading level0 row1" >physical_score</th>
#                         <td id="T_53637_row1_col0" class="data row1 col0" >-0.782146</td>
#                         <td id="T_53637_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_53637_row1_col2" class="data row1 col2" >0.792716</td>
#             </tr>
#             <tr>
#                         <th id="T_53637_level0_row2" class="row_heading level0 row2" >test_result</th>
#                         <td id="T_53637_row2_col0" class="data row2 col0" >-0.683171</td>
#                         <td id="T_53637_row2_col1" class="data row2 col1" >0.792716</td>
#                         <td id="T_53637_row2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### select input and op variable

# %%
x = df.drop(['test_result'], axis=1)
y = df['test_result']

# %% [markdown]
# ### splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 123456, train_size= 0.8)

# %% [markdown]
# ### creating a model

# %%
from sklearn.svm import SVC
model = SVC(C = 2)

# %%
## fit the data
model.fit(x_train, y_train)
# Out:
# SVC(C=2)

# %% [markdown]
# ### parameters to fine tune model

# %%
print(model.get_params())
# Out:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %% [markdown]
# ### predict the values for unseen data

# %%
y_prediction = model.predict(x_test)
#print(y_prediction)

# %% [markdown]
# ### evaluation of classification model

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_prediction)
print(cm)
# Out:
# [[339  54]
#  [ 21 586]]

# %%
correct = cm[0,0] + cm[1,1]
wrong = cm[1,0] + cm[0,1]
total = correct + wrong
accuracy = correct/total
print(accuracy)
# Out:
# 0.925

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_prediction))
# Out:
# 0.925

# %% [markdown]
# ### precision value

# %%
from sklearn.metrics import precision_score
print(precision_score(y_test, y_prediction))
# Out:
# 0.915625

# %% [markdown]
# ### recal value

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test, y_prediction))
# Out:
# 0.9654036243822076

# %% [markdown]
# ### F1 score

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test, y_prediction))
# Out:
# 0.9398556535685646

# %% [markdown]
# ### classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90       393
#            1       0.92      0.97      0.94       607
#
#     accuracy                           0.93      1000
#    macro avg       0.93      0.91      0.92      1000
# weighted avg       0.93      0.93      0.92      1000

# %%
from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve

print(roc_auc_score(y_test, y_prediction))
# Out:
# 0.9139995221147679

# %%
fpr, tpr, threshold = roc_curve(y_test, y_prediction)
print(fpr)
print(tpr)
print(threshold)
plt.plot(fpr, tpr)
# Out:
# [0.         0.13740458 1.        ]
# [0.         0.96540362 1.        ]
# [2 1 0]

# %%
plot = plot_roc_curve(model, x_test, y_test)
plt.plot([0,1], [0,1], linestyle = '--')
